# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import os

# %%
# get data and read
pth = os.path.abspath(os.curdir) + os.sep + 'data' + os.sep + 'nuts3.shp'
nuts = gpd.read_file(pth)

# %%
nuts = nuts.cx[:,30:90]
nuts.plot(figsize=(10, 6));

# %%
nuts.plot()
